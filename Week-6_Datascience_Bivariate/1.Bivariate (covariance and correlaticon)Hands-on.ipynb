# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
from Univariate import Univariate

# %%
quan,qual=Univariate.quan_qual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
from Univariate import Univariate
import pandas as pd
descriptive= Univariate.descriptive_Tab(dataset,quan)

# %%
descriptive
# Out:
#               sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p   salary
# Mean            108  67.3034  66.3332  66.3702  72.1006  62.2782   288655
# Median          108       67       65       66       71       62   288655
# Mode              1       62       63       65       60     56.7   288655
# Q1:25%         54.5     60.6     60.9       61       60   57.945   250000
# Q2:50%          108       67       65       66       71       62   288655
# Q3:75%        161.5     75.7       73       72     83.5   66.255   288655
# 99%          212.86       87    91.86    83.86       97  76.1142   629000
# Q4:100%         215     89.4     97.7       91       98    77.89   940000
# IQR             107     15.1     12.1       11     23.5     8.31  38655.4
# 1.5rule       160.5    22.65    18.15     16.5    35.25   12.465  57983.1
# lesser_per     -106    37.95    42.75     44.5    24.75    45.48   192017
# greater_per     322    98.35    91.15     88.5   118.75    78.72   346639
# ...

# %%
lesser_de,greater_de=Univariate.detect_lesser_greater(quan,descriptive)

# %%
lesser_de
# Out:
# ['hsc_p']

# %%
greater_de
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# #so we have to replace outliers.

# %%
def Replace_outliers(dataset,lesser_de,greater_de,descriptive):
    for column_names in lesser_de:
        dataset[column_names][dataset[column_names]<descriptive[column_names]["lesser_per"]]=descriptive[column_names]["lesser_per"]
    for column_names in greater_de:
        dataset[column_names][dataset[column_names]>descriptive[column_names]["greater_per"]]=descriptive[column_names]["greater_per"]
    return descriptive

# %%
Replace_outliers(dataset,lesser_de,greater_de,descriptive)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#               sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p   salary
# Mean            108  67.3034  66.3332  66.3702  72.1006  62.2782   288655
# Median          108       67       65       66       71       62   288655
# Mode              1       62       63       65       60     56.7   288655
# ...

# %%
from Univariate import Univariate
import pandas as pd
Univariate.Replace_outliers(dataset,lesser_de,greater_de,descriptive)
# Out:
# D:\Week-6_Datascience_Bivariate\Univariate.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[column_names][dataset[column_names]<descriptive[column_names]["lesser_per"]]=descriptive[column_names]
# D:\Week-6_Datascience_Bivariate\Univariate.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[column_names][dataset[column_names]>descriptive[column_names]["greater_per"]]=descriptive[column_names]
#               sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p   salary
# Mean            108  67.3034  66.3332  66.3702  72.1006  62.2782   288655
# ...

# %%
Preprocessed_disc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21460\2422002513.py in <module>
# ----> 1 Preprocessed_disc
#
# NameError: name 'Preprocessed_disc' is not defined

# %%
lesser_de,greater_de=Univariate.detect_lesser_greater(quan,Preprocessed_disc)

# %%
lesser_de

# %%
greater_de
